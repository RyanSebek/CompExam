# %%
import pandas as pd
df = pd.read_csv("insurance.csv")
df.head
# Out:
# <bound method NDFrame.head of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]>

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
ax = sns.scatterplot(data = df, x = 'age', y = 'bmi')

# %%
import numpy as np

numeric_df = df.select_dtypes(include='number',)
rs = np.random.RandomState(42)
corr = numeric_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_49022_row0_col0, #T_49022_row1_col1, #T_49022_row2_col2, #T_49022_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_49022_row0_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_49022_row0_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_49022_row0_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_49022_row1_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_49022_row1_col2, #T_49022_row2_col0, #T_49022_row2_col1, #T_49022_row2_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_49022_row1_col3 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_49022_row3_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_49022_row3_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_49022_row3_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_49022">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49022_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_49022_level0_col1" class="col_heading level0 col1" >bmi</th>
#       <th id="T_49022_level0_col2" class="col_heading level0 col2" >children</th>
#       <th id="T_49022_level0_col3" class="col_heading level0 col3" >charges</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49022_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_49022_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_49022_row0_col1" class="data row0 col1" >0.109272</td>
#       <td id="T_49022_row0_col2" class="data row0 col2" >0.042469</td>
#       <td id="T_49022_row0_col3" class="data row0 col3" >0.299008</td>
#     </tr>
#     <tr>
#       <th id="T_49022_level0_row1" class="row_heading level0 row1" >bmi</th>
#       <td id="T_49022_row1_col0" class="data row1 col0" >0.109272</td>
#       <td id="T_49022_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_49022_row1_col2" class="data row1 col2" >0.012759</td>
#       <td id="T_49022_row1_col3" class="data row1 col3" >0.198341</td>
#     </tr>
#     <tr>
#       <th id="T_49022_level0_row2" class="row_heading level0 row2" >children</th>
#       <td id="T_49022_row2_col0" class="data row2 col0" >0.042469</td>
#       <td id="T_49022_row2_col1" class="data row2 col1" >0.012759</td>
#       <td id="T_49022_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_49022_row2_col3" class="data row2 col3" >0.067998</td>
#     </tr>
#     <tr>
#       <th id="T_49022_level0_row3" class="row_heading level0 row3" >charges</th>
#       <td id="T_49022_row3_col0" class="data row3 col0" >0.299008</td>
#       <td id="T_49022_row3_col1" class="data row3 col1" >0.198341</td>
#       <td id="T_49022_row3_col2" class="data row3 col2" >0.067998</td>
#       <td id="T_49022_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['sex'] = le.fit_transform(df['sex'])
df['smoker'] = le.fit_transform(df['smoker'])
df['region'] = le.fit_transform(df['region'])

# %%
numeric_df = df.select_dtypes(include='number',)
rs = np.random.RandomState(42)
corr = numeric_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f7d91_row0_col0, #T_f7d91_row1_col1, #T_f7d91_row2_col2, #T_f7d91_row3_col3, #T_f7d91_row4_col4, #T_f7d91_row5_col5, #T_f7d91_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f7d91_row0_col1, #T_f7d91_row0_col4, #T_f7d91_row4_col0, #T_f7d91_row4_col2, #T_f7d91_row4_col3, #T_f7d91_row5_col6, #T_f7d91_row6_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f7d91_row0_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_f7d91_row0_col3, #T_f7d91_row3_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_f7d91_row0_col5, #T_f7d91_row1_col3, #T_f7d91_row1_col5, #T_f7d91_row3_col2, #T_f7d91_row5_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_f7d91_row0_col6 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_f7d91_row1_col0, #T_f7d91_row2_col3, #T_f7d91_row4_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_f7d91_row1_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_f7d91_row1_col4 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_f7d91_row1_col6, #T_f7d91_row2_col1, #T_f7d91_row3_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_f7d91_row2_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_f7d91_row2_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_f7d91_row2_col5 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_f7d91_row2_col6 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_f7d91_row3_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_f7d91_row3_col5, #T_f7d91_row5_col4 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_f7d91_row3_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_f7d91_row4_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_f7d91_row4_col6 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_f7d91_row5_col0, #T_f7d91_row5_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_f7d91_row5_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_f7d91_row6_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_f7d91_row6_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_f7d91_row6_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_f7d91_row6_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_f7d91_row6_col4 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f7d91">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7d91_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_f7d91_level0_col1" class="col_heading level0 col1" >sex</th>
#       <th id="T_f7d91_level0_col2" class="col_heading level0 col2" >bmi</th>
#       <th id="T_f7d91_level0_col3" class="col_heading level0 col3" >children</th>
#       <th id="T_f7d91_level0_col4" class="col_heading level0 col4" >smoker</th>
#       <th id="T_f7d91_level0_col5" class="col_heading level0 col5" >region</th>
#       <th id="T_f7d91_level0_col6" class="col_heading level0 col6" >charges</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7d91_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_f7d91_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f7d91_row0_col1" class="data row0 col1" >-0.020856</td>
#       <td id="T_f7d91_row0_col2" class="data row0 col2" >0.109272</td>
#       <td id="T_f7d91_row0_col3" class="data row0 col3" >0.042469</td>
#       <td id="T_f7d91_row0_col4" class="data row0 col4" >-0.025019</td>
#       <td id="T_f7d91_row0_col5" class="data row0 col5" >0.002127</td>
#       <td id="T_f7d91_row0_col6" class="data row0 col6" >0.299008</td>
#     </tr>
#     <tr>
#       <th id="T_f7d91_level0_row1" class="row_heading level0 row1" >sex</th>
#       <td id="T_f7d91_row1_col0" class="data row1 col0" >-0.020856</td>
#       <td id="T_f7d91_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f7d91_row1_col2" class="data row1 col2" >0.046371</td>
#       <td id="T_f7d91_row1_col3" class="data row1 col3" >0.017163</td>
#       <td id="T_f7d91_row1_col4" class="data row1 col4" >0.076185</td>
#       <td id="T_f7d91_row1_col5" class="data row1 col5" >0.004588</td>
#       <td id="T_f7d91_row1_col6" class="data row1 col6" >0.057292</td>
#     </tr>
#     <tr>
#       <th id="T_f7d91_level0_row2" class="row_heading level0 row2" >bmi</th>
#       <td id="T_f7d91_row2_col0" class="data row2 col0" >0.109272</td>
#       <td id="T_f7d91_row2_col1" class="data row2 col1" >0.046371</td>
#       <td id="T_f7d91_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_f7d91_row2_col3" class="data row2 col3" >0.012759</td>
#       <td id="T_f7d91_row2_col4" class="data row2 col4" >0.003750</td>
#       <td id="T_f7d91_row2_col5" class="data row2 col5" >0.157566</td>
#       <td id="T_f7d91_row2_col6" class="data row2 col6" >0.198341</td>
#     </tr>
#     <tr>
#       <th id="T_f7d91_level0_row3" class="row_heading level0 row3" >children</th>
#       <td id="T_f7d91_row3_col0" class="data row3 col0" >0.042469</td>
#       <td id="T_f7d91_row3_col1" class="data row3 col1" >0.017163</td>
#       <td id="T_f7d91_row3_col2" class="data row3 col2" >0.012759</td>
#       <td id="T_f7d91_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_f7d91_row3_col4" class="data row3 col4" >0.007673</td>
#       <td id="T_f7d91_row3_col5" class="data row3 col5" >0.016569</td>
#       <td id="T_f7d91_row3_col6" class="data row3 col6" >0.067998</td>
#     </tr>
#     <tr>
#       <th id="T_f7d91_level0_row4" class="row_heading level0 row4" >smoker</th>
#       <td id="T_f7d91_row4_col0" class="data row4 col0" >-0.025019</td>
#       <td id="T_f7d91_row4_col1" class="data row4 col1" >0.076185</td>
#       <td id="T_f7d91_row4_col2" class="data row4 col2" >0.003750</td>
#       <td id="T_f7d91_row4_col3" class="data row4 col3" >0.007673</td>
#       <td id="T_f7d91_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_f7d91_row4_col5" class="data row4 col5" >-0.002181</td>
#       <td id="T_f7d91_row4_col6" class="data row4 col6" >0.787251</td>
#     </tr>
#     <tr>
#       <th id="T_f7d91_level0_row5" class="row_heading level0 row5" >region</th>
#       <td id="T_f7d91_row5_col0" class="data row5 col0" >0.002127</td>
#       <td id="T_f7d91_row5_col1" class="data row5 col1" >0.004588</td>
#       <td id="T_f7d91_row5_col2" class="data row5 col2" >0.157566</td>
#       <td id="T_f7d91_row5_col3" class="data row5 col3" >0.016569</td>
#       <td id="T_f7d91_row5_col4" class="data row5 col4" >-0.002181</td>
#       <td id="T_f7d91_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_f7d91_row5_col6" class="data row5 col6" >-0.006208</td>
#     </tr>
#     <tr>
#       <th id="T_f7d91_level0_row6" class="row_heading level0 row6" >charges</th>
#       <td id="T_f7d91_row6_col0" class="data row6 col0" >0.299008</td>
#       <td id="T_f7d91_row6_col1" class="data row6 col1" >0.057292</td>
#       <td id="T_f7d91_row6_col2" class="data row6 col2" >0.198341</td>
#       <td id="T_f7d91_row6_col3" class="data row6 col3" >0.067998</td>
#       <td id="T_f7d91_row6_col4" class="data row6 col4" >0.787251</td>
#       <td id="T_f7d91_row6_col5" class="data row6 col5" >-0.006208</td>
#       <td id="T_f7d91_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.linear_model import LinearRegression
X = df[['charges','region','age']]
Y = df['bmi']

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=42)

model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)
print(Y_pred[:5])
# Out:
# [28.89664992 29.25485578 32.09341924 29.85905843 31.39897113]

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
print(f"Mean Squared Error: {mse:.2f}")
print(f"R^2 Score: {r2:.2f}")
# Out:
# Mean Squared Error: 38.02
# R^2 Score: 0.05
